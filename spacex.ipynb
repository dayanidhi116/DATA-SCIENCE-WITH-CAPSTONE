# %% [markdown]
# <a href="https://colab.research.google.com/github/dayanidhi116/DATA-SCIENCE-WITH-CAPSTONE/blob/main/spacex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from datetime import datetime

# API endpoint
spacex_url = "https://api.spacexdata.com/v4/launches/past"

# Fetch data
response = requests.get(spacex_url)

# Check if request was successful
if response.status_code == 200:
    launches = response.json()

    # Print structured data
    for launch in launches:
        name = launch.get('name', 'N/A')
        date_utc = launch.get('date_utc', 'N/A')
        date_local = datetime.strptime(date_utc, "%Y-%m-%dT%H:%M:%S.%fZ")
        success = launch.get('success', 'N/A')

        print(f"Name: {name}")
        print(f"Date (UTC): {date_local.strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"Success: {success}")
        print("-" * 40)

else:
    print("Failed to retrieve data. Status code:", response.status_code)
# Out:
# Name: FalconSat
# Date (UTC): 2006-03-24 22:30:00
# Success: False
# ----------------------------------------
# Name: DemoSat
# Date (UTC): 2007-03-21 01:10:00
# Success: False
# ----------------------------------------
# Name: Trailblazer
# Date (UTC): 2008-08-03 03:34:00
# Success: False
# ----------------------------------------
# Name: RatSat
# Date (UTC): 2008-09-28 23:15:00
# Success: True
# ----------------------------------------
# Name: RazakSat
# Date (UTC): 2009-07-13 03:35:00
# Success: True
# ----------------------------------------
# Name: Falcon 9 Test Flight
# Date (UTC): 2010-06-04 18:45:00
# Success: True
# ----------------------------------------
# Name: COTS 1
# Date (UTC): 2010-12-08 15:43:00
# Success: True
# ----------------------------------------
# Name: COTS 2
# Date (UTC): 2012-05-22 07:44:00
# Success: True
# ----------------------------------------
# Name: CRS-1
# Date (UTC): 2012-10-08 00:35:00
# Success: True
# ----------------------------------------
# Name: CRS-2
# Date (UTC): 2013-03-01 19:10:00
# Success: True
# ----------------------------------------
# Name: CASSIOPE
# Date (UTC): 2013-09-29 16:00:00
# Success: True
# ----------------------------------------
# Name: SES-8
# Date (UTC): 2013-12-03 22:41:00
# Success: True
# ----------------------------------------
# Name: Thaicom 6
# Date (UTC): 2014-01-06 18:06:00
# Success: True
# ----------------------------------------
# Name: CRS-3
# Date (UTC): 2014-04-18 19:25:00
# Success: True
# ----------------------------------------
# Name: OG-2 Mission 1
# Date (UTC): 2014-07-14 15:15:00
# Success: True
# ----------------------------------------
# Name: AsiaSat 8
# Date (UTC): 2014-08-05 08:00:00
# Success: True
# ----------------------------------------
# Name: AsiaSat 6
# Date (UTC): 2014-09-07 05:00:00
# Success: True
# ----------------------------------------
# Name: CRS-4
# Date (UTC): 2014-09-21 05:52:00
# Success: True
# ----------------------------------------
# Name: CRS-5
# Date (UTC): 2015-01-10 09:47:00
# Success: True
# ----------------------------------------
# Name: DSCOVR
# Date (UTC): 2015-02-11 23:03:00
# Success: True
# ----------------------------------------
# Name: ABS-3A / Eutelsat 115W B
# Date (UTC): 2015-03-02 03:50:00
# Success: True
# ----------------------------------------
# Name: CRS-6
# Date (UTC): 2015-04-14 20:10:00
# Success: True
# ----------------------------------------
# Name: TürkmenÄlem 52°E / MonacoSAT
# Date (UTC): 2015-04-27 23:03:00
# Success: True
# ----------------------------------------
# Name: CRS-7
# Date (UTC): 2015-06-28 14:21:00
# Success: False
# ----------------------------------------
# Name: OG-2 Mission 2
# Date (UTC): 2015-12-22 01:29:00
# Success: True
# ----------------------------------------
# Name: Jason 3
# Date (UTC): 2016-01-17 15:42:00
# Success: True
# ----------------------------------------
# Name: SES-9
# Date (UTC): 2016-03-04 23:35:00
# Success: True
# ----------------------------------------
# Name: CRS-8
# Date (UTC): 2016-04-08 20:43:00
# Success: True
# ----------------------------------------
# Name: JCSAT-2B
# Date (UTC): 2016-05-06 05:21:00
# Success: True
# ----------------------------------------
# Name: Thaicom 8
# Date (UTC): 2016-05-27 21:39:00
# Success: True
# ----------------------------------------
# Name: ABS-2A / Eutelsat 117W B
# Date (UTC): 2016-06-15 14:29:00
# Success: True
# ----------------------------------------
# Name: CRS-9
# Date (UTC): 2016-07-18 04:45:00
# Success: True
# ----------------------------------------
# Name: JCSAT-16
# Date (UTC): 2016-08-14 05:26:00
# Success: True
# ----------------------------------------
# Name: Amos-6
# Date (UTC): 2016-09-01 13:07:00
# Success: False
# ----------------------------------------
# Name: Iridium NEXT Mission 1
# Date (UTC): 2017-01-14 17:54:00
# Success: True
# ----------------------------------------
# Name: CRS-10
# Date (UTC): 2017-02-19 14:39:00
# Success: True
# ----------------------------------------
# Name: EchoStar 23
# Date (UTC): 2017-03-16 06:00:00
# Success: True
# ----------------------------------------
# Name: SES-10
# Date (UTC): 2017-03-30 22:27:00
# Success: True
# ----------------------------------------
# Name: NROL-76
# Date (UTC): 2017-05-01 11:15:00
# Success: True
# ----------------------------------------
# Name: Inmarsat-5 F4
# Date (UTC): 2017-05-15 23:21:00
# Success: True
# ----------------------------------------
# Name: CRS-11
# Date (UTC): 2017-06-03 21:07:00
# Success: True
# ----------------------------------------
# Name: BulgariaSat-1
# Date (UTC): 2017-06-23 19:10:00
# Success: True
# ----------------------------------------
# Name: Iridium NEXT Mission 2
# Date (UTC): 2017-06-25 20:25:00
# Success: True
# ----------------------------------------
# Name: Intelsat 35e
# Date (UTC): 2017-07-05 23:35:00
# Success: True
# ----------------------------------------
# Name: CRS-12
# Date (UTC): 2017-08-14 16:31:00
# Success: True
# ----------------------------------------
# Name: FormoSat-5
# Date (UTC): 2017-08-24 18:50:00
# Success: True
# ----------------------------------------
# Name: Boeing X-37B OTV-5
# Date (UTC): 2017-09-07 13:50:00
# Success: True
# ----------------------------------------
# Name: Iridium NEXT Mission 3
# Date (UTC): 2017-10-09 12:37:00
# Success: True
# ----------------------------------------
# Name: SES-11 / Echostar 105
# Date (UTC): 2017-10-11 22:53:00
# Success: True
# ----------------------------------------
# Name: KoreaSat 5A
# Date (UTC): 2017-10-30 19:34:00
# Success: True
# ----------------------------------------
# Name: CRS-13
# Date (UTC): 2017-12-15 15:36:00
# Success: True
# ----------------------------------------
# Name: Iridium NEXT Mission 4
# Date (UTC): 2017-12-23 01:27:23
# Success: True
# ----------------------------------------
# Name: ZUMA
# Date (UTC): 2018-01-08 01:00:00
# Success: True
# ----------------------------------------
# Name: SES-16 / GovSat-1
# Date (UTC): 2018-01-31 21:25:00
# Success: True
# ----------------------------------------
# Name: Falcon Heavy Test Flight
# Date (UTC): 2018-02-06 20:45:00
# Success: True
# ----------------------------------------
# Name: Paz / Starlink Demo
# Date (UTC): 2018-02-22 14:17:00
# Success: True
# ----------------------------------------
# Name: Hispasat 30W-6
# Date (UTC): 2018-03-06 05:33:00
# Success: True
# ----------------------------------------
# Name: Iridium NEXT Mission 5
# Date (UTC): 2018-03-30 14:13:51
# Success: True
# ----------------------------------------
# Name: CRS-14
# Date (UTC): 2018-04-02 20:30:41
# Success: True
# ----------------------------------------
# Name: TESS
# Date (UTC): 2018-04-18 22:51:00
# Success: True
# ----------------------------------------
# Name: Bangabandhu-1
# Date (UTC): 2018-05-11 20:14:00
# Success: True
# ----------------------------------------
# Name: Iridium NEXT Mission 6
# Date (UTC): 2018-05-22 19:47:58
# Success: True
# ----------------------------------------
# Name: SES-12
# Date (UTC): 2018-06-04 04:45:00
# Success: True
# ----------------------------------------
# Name: CRS-15
# Date (UTC): 2018-06-29 09:42:00
# Success: True
# ----------------------------------------
# Name: Telstar 19V
# Date (UTC): 2018-07-22 05:50:00
# Success: True
# ----------------------------------------
# Name: Iridium NEXT Mission 7
# Date (UTC): 2018-07-25 11:39:26
# Success: True
# ----------------------------------------
# Name: Merah Putih
# Date (UTC): 2018-08-07 05:18:00
# Success: True
# ----------------------------------------
# Name: Telstar 18V
# Date (UTC): 2018-09-10 04:45:00
# Success: True
# ----------------------------------------
# Name: SAOCOM 1A
# Date (UTC): 2018-10-08 02:22:00
# Success: True
# ----------------------------------------
# Name: Es’hail 2
# Date (UTC): 2018-11-15 20:46:00
# Success: True
# ----------------------------------------
# Name: SSO-A
# Date (UTC): 2018-12-03 18:34:00
# Success: True
# ----------------------------------------
# Name: CRS-16
# Date (UTC): 2018-12-05 18:16:00
# Success: True
# ----------------------------------------
# Name: GPS III SV01
# Date (UTC): 2018-12-23 13:51:00
# Success: True
# ----------------------------------------
# Name: Iridium NEXT Mission 8
# Date (UTC): 2019-01-11 15:31:00
# Success: True
# ----------------------------------------
# Name: Nusantara Satu (PSN-6) / S5 / Beresheet
# Date (UTC): 2019-02-22 01:45:00
# Success: True
# ----------------------------------------
# Name: CCtCap Demo Mission 1
# Date (UTC): 2019-03-02 07:45:00
# Success: True
# ----------------------------------------
# Name: ArabSat 6A
# Date (UTC): 2019-04-11 22:35:00
# Success: True
# ----------------------------------------
# Name: CRS-17
# Date (UTC): 2019-05-04 06:48:00
# Success: True
# ----------------------------------------
# Name: Starlink v0.9
# Date (UTC): 2019-05-24 02:30:00
# Success: True
# ----------------------------------------
# Name: RADARSAT Constellation
# Date (UTC): 2019-06-12 14:17:00
# Success: True
# ----------------------------------------
# Name: STP-2
# Date (UTC): 2019-06-25 03:30:00
# Success: True
# ----------------------------------------
# Name: CRS-18
# Date (UTC): 2019-07-25 22:01:00
# Success: True
# ----------------------------------------
# Name: Amos-17
# Date (UTC): 2019-08-06 22:52:00
# Success: True
# ----------------------------------------
# Name: Starlink-1
# Date (UTC): 2019-11-11 14:56:00
# Success: True
# ----------------------------------------
# Name: CRS-19
# Date (UTC): 2019-12-05 17:29:23
# Success: True
# ----------------------------------------
# Name: JCSat 18 / Kacific 1
# Date (UTC): 2019-12-17 00:10:00
# Success: True
# ----------------------------------------
# Name: Starlink-2
# Date (UTC): 2020-01-07 02:19:00
# Success: True
# ----------------------------------------
# Name: Crew Dragon In Flight Abort Test
# Date (UTC): 2020-01-19 14:00:00
# Success: True
# ----------------------------------------
# Name: Starlink-3
# Date (UTC): 2020-01-29 14:06:00
# Success: True
# ----------------------------------------
# Name: Starlink-4
# Date (UTC): 2020-02-17 15:05:55
# Success: True
# ----------------------------------------
# Name: CRS-20
# Date (UTC): 2020-03-07 04:50:31
# Success: True
# ----------------------------------------
# Name: Starlink-5
# Date (UTC): 2020-03-18 12:16:00
# Success: True
# ----------------------------------------
# Name: Starlink-6
# Date (UTC): 2020-04-22 19:30:00
# Success: True
# ----------------------------------------
# Name: CCtCap Demo Mission 2
# Date (UTC): 2020-05-30 19:22:00
# Success: True
# ----------------------------------------
# Name: Starlink-7
# Date (UTC): 2020-06-04 01:25:00
# Success: True
# ----------------------------------------
# Name: Starlink-8 & SkySat 16-18
# Date (UTC): 2020-06-13 09:21:00
# Success: True
# ----------------------------------------
# Name: GPS III SV03 (Columbus)
# Date (UTC): 2020-06-30 19:55:00
# Success: True
# ----------------------------------------
# Name: ANASIS-II
# Date (UTC): 2020-07-20 21:30:00
# Success: True
# ----------------------------------------
# Name: Starlink-9 (v1.0) & BlackSky Global 5-6
# Date (UTC): 2020-08-07 05:12:00
# Success: True
# ----------------------------------------
# Name: Starlink-10 (v1.0) & SkySat 19-21
# Date (UTC): 2020-08-18 14:31:00
# Success: True
# ----------------------------------------
# Name: SAOCOM 1B, GNOMES-1, Tyvak-0172
# Date (UTC): 2020-08-30 23:18:00
# Success: True
# ----------------------------------------
# Name: Starlink-11 (v1.0)
# Date (UTC): 2020-09-03 12:46:00
# Success: True
# ----------------------------------------
# Name: Starlink-12 (v1.0)
# Date (UTC): 2020-10-06 11:29:00
# Success: True
# ----------------------------------------
# Name: Starlink-13 (v1.0)
# Date (UTC): 2020-10-18 12:25:00
# Success: True
# ----------------------------------------
# Name: Starlink-14 (v1.0)
# Date (UTC): 2020-10-24 15:31:00
# Success: True
# ----------------------------------------
# Name: GPS III SV04 (Sacagawea)
# Date (UTC): 2020-11-05 23:24:00
# Success: True
# ----------------------------------------
# Name: Crew-1
# Date (UTC): 2020-11-16 00:27:00
# Success: True
# ----------------------------------------
# Name: Sentinel-6 Michael Freilich
# Date (UTC): 2020-11-21 17:17:00
# Success: True
# ----------------------------------------
# Name: Starlink-15 (v1.0)
# Date (UTC): 2020-11-25 02:13:00
# Success: True
# ----------------------------------------
# Name: CRS-21
# Date (UTC): 2020-12-06 16:17:00
# Success: True
# ----------------------------------------
# Name: SXM-7
# Date (UTC): 2020-12-13 17:30:00
# Success: True
# ----------------------------------------
# Name: NROL-108
# Date (UTC): 2020-12-19 14:00:00
# Success: True
# ----------------------------------------
# Name: Turksat 5A
# Date (UTC): 2021-01-08 02:15:00
# Success: True
# ----------------------------------------
# Name: Starlink-16 (v1.0)
# Date (UTC): 2021-01-20 13:02:00
# Success: True
# ----------------------------------------
# Name: Transporter-1
# Date (UTC): 2021-01-24 15:00:00
# Success: True
# ----------------------------------------
# Name: Starlink-18 (v1.0)
# Date (UTC): 2021-02-04 06:19:00
# Success: True
# ----------------------------------------
# Name: Starlink-19 (v1.0)
# Date (UTC): 2021-02-16 03:59:00
# Success: True
# ----------------------------------------
# Name: Starlink-17 (v1.0)
# Date (UTC): 2021-03-04 08:24:00
# Success: True
# ----------------------------------------
# Name: Starlink-20 (v1.0)
# Date (UTC): 2021-03-11 08:13:00
# Success: True
# ----------------------------------------
# Name: Starlink-21 (v1.0)
# Date (UTC): 2021-03-14 10:01:00
# Success: True
# ----------------------------------------
# Name: Starlink-22 (v1.0)
# Date (UTC): 2021-03-24 08:28:00
# Success: True
# ----------------------------------------
# Name: Starlink-23 (v1.0)
# Date (UTC): 2021-04-07 16:34:00
# Success: True
# ----------------------------------------
# Name: Crew-2
# Date (UTC): 2021-04-23 09:49:00
# Success: True
# ----------------------------------------
# Name: Starlink-24 (v1.0)
# Date (UTC): 2021-04-29 03:44:00
# Success: True
# ----------------------------------------
# Name: Starlink-25 (v1.0)
# Date (UTC): 2021-05-04 19:01:00
# Success: True
# ----------------------------------------
# Name: Starlink-27 (v1.0)
# Date (UTC): 2021-05-09 06:42:00
# Success: True
# ----------------------------------------
# Name: Starlink-26 (v1.0) + Capella-6 + Tyvak-0130
# Date (UTC): 2021-05-15 22:54:00
# Success: True
# ----------------------------------------
# Name: Starlink-28 (v1.0)
# Date (UTC): 2021-05-26 18:59:00
# Success: True
# ----------------------------------------
# Name: CRS-22 & IROSA
# Date (UTC): 2021-06-03 17:29:00
# Success: True
# ----------------------------------------
# Name: SXM-8
# Date (UTC): 2021-06-06 04:26:00
# Success: True
# ----------------------------------------
# Name: GPS III SV05
# Date (UTC): 2021-06-17 16:09:00
# Success: True
# ----------------------------------------
# Name: Transporter-2
# Date (UTC): 2021-06-30 19:31:00
# Success: True
# ----------------------------------------
# Name: CRS-23
# Date (UTC): 2021-08-29 07:14:00
# Success: True
# ----------------------------------------
# Name: Starlink 2-1 (v1.5)
# Date (UTC): 2021-09-14 03:55:00
# Success: True
# ----------------------------------------
# Name: Inspiration4
# Date (UTC): 2021-09-16 00:02:00
# Success: True
# ----------------------------------------
# Name: Crew-3
# Date (UTC): 2021-11-11 02:03:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-1 (v1.5)
# Date (UTC): 2021-11-13 12:40:00
# Success: True
# ----------------------------------------
# Name: DART
# Date (UTC): 2021-11-24 06:20:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-3 (v1.5)
# Date (UTC): 2021-12-01 23:20:00
# Success: True
# ----------------------------------------
# Name: IXPE
# Date (UTC): 2021-12-09 06:00:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-4 (v1.5)
# Date (UTC): 2021-12-18 12:41:40
# Success: True
# ----------------------------------------
# Name: Türksat 5B
# Date (UTC): 2021-12-19 03:58:00
# Success: True
# ----------------------------------------
# Name: CRS-24
# Date (UTC): 2021-12-21 10:06:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-5 (v1.5)
# Date (UTC): 2022-01-06 21:49:00
# Success: True
# ----------------------------------------
# Name: Transporter-3
# Date (UTC): 2022-01-13 15:25:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-6 (v1.5)
# Date (UTC): 2022-01-19 00:04:00
# Success: True
# ----------------------------------------
# Name: CSG-2
# Date (UTC): 2022-01-31 23:11:12
# Success: True
# ----------------------------------------
# Name: NROL-87
# Date (UTC): 2022-02-02 20:18:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-7 (v1.5)
# Date (UTC): 2022-02-03 18:13:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-8 (v1.5)
# Date (UTC): 2022-02-21 14:44:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-11 (v1.5)
# Date (UTC): 2022-02-25 17:12:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-9 (v1.5)
# Date (UTC): 2022-03-03 14:35:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-10 (v1.5)
# Date (UTC): 2022-03-09 13:45:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-12 (v1.5)
# Date (UTC): 2022-03-19 03:24:00
# Success: True
# ----------------------------------------
# Name: Transporter-4
# Date (UTC): 2022-04-01 16:24:00
# Success: True
# ----------------------------------------
# Name: Ax-1
# Date (UTC): 2022-04-08 15:17:00
# Success: True
# ----------------------------------------
# Name: NROL-85
# Date (UTC): 2022-04-17 13:13:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-14 (v1.5)
# Date (UTC): 2022-04-21 15:16:00
# Success: True
# ----------------------------------------
# Name: Crew-4
# Date (UTC): 2022-04-27 07:52:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-16 (v1.5)
# Date (UTC): 2022-04-29 21:27:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-17 (v1.5)
# Date (UTC): 2022-05-06 09:42:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-13 (v1.5)
# Date (UTC): 2022-05-13 22:07:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-15 (v1.5)
# Date (UTC): 2022-05-14 20:40:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-18 (v1.5)
# Date (UTC): 2022-05-18 10:40:00
# Success: True
# ----------------------------------------
# Name: Transporter-5
# Date (UTC): 2022-05-25 18:27:00
# Success: True
# ----------------------------------------
# Name: Nilesat-301
# Date (UTC): 2022-06-08 21:04:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-19 (v1.5)
# Date (UTC): 2022-06-01 17:08:50
# Success: True
# ----------------------------------------
# Name: SARah 1
# Date (UTC): 2022-06-18 14:19:00
# Success: True
# ----------------------------------------
# Name: Globalstar FM15
# Date (UTC): 2022-06-19 04:27:00
# Success: True
# ----------------------------------------
# Name: SES-22
# Date (UTC): 2022-06-29 21:04:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-21 (v1.5)
# Date (UTC): 2022-07-07 13:11:00
# Success: True
# ----------------------------------------
# Name: Starlink 3-1 (v1.5)
# Date (UTC): 2022-07-11 01:39:00
# Success: None
# ----------------------------------------
# Name: CRS-25
# Date (UTC): 2022-07-15 00:44:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-22 (v1.5)
# Date (UTC): 2022-07-17 14:50:00
# Success: True
# ----------------------------------------
# Name: Starlink 3-2 (v1.5)
# Date (UTC): 2022-07-21 17:13:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-25 (v1.5)
# Date (UTC): 2022-07-24 00:00:00
# Success: True
# ----------------------------------------
# Name: KPLO
# Date (UTC): 2022-08-04 23:08:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-26 (v1.5)
# Date (UTC): 2022-08-09 22:57:00
# Success: True
# ----------------------------------------
# Name: Starlink 3-3 (v1.5)
# Date (UTC): 2022-08-12 21:30:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-27 (v1.5)
# Date (UTC): 2022-08-19 19:24:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-23 (v1.5)
# Date (UTC): 2022-08-28 02:22:00
# Success: True
# ----------------------------------------
# Name: Starlink 3-4 (v1.5)
# Date (UTC): 2022-08-31 05:40:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-20 (v1.5) & Sherpa LTC-2/Varuna-TDM
# Date (UTC): 2022-09-05 02:09:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-2 (v1.5) & Blue Walker 3
# Date (UTC): 2022-09-11 01:10:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-34 (v1.5)
# Date (UTC): 2022-09-17 01:05:00
# Success: True
# ----------------------------------------
# Name: Starlink 4-35 (v1.5)
# Date (UTC): 2022-09-24 23:30:00
# Success: True
# ----------------------------------------
# Name: Crew-5
# Date (UTC): 2022-10-05 16:00:00
# Success: True
# ----------------------------------------

# %%
import pandas as pd
import numpy as np
import requests
import datetime

# Static SpaceX launch dataset
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/' \
      'IBM-DS0321EN-SkillsNetwork/datasets/API_call_spacex_api.json'

response = requests.get(url)
data = pd.json_normalize(response.json())

# Select relevant columns
data = data[['rocket', 'payloads', 'launchpad', 'cores', 'flight_number', 'date_utc']]

# Filter for single-core and single-payload launches
data = data[data['cores'].map(len) == 1]
data = data[data['payloads'].map(len) == 1]

# Flatten core and payload fields
data['cores'] = data['cores'].apply(lambda x: x[0])
data['payloads'] = data['payloads'].apply(lambda x: x[0])

# Convert date
data['date'] = pd.to_datetime(data['date_utc']).dt.date

# Filter by date
data = data[data['date'] <= datetime.date(2020, 11, 13)]

# Normalize nested core and payload data
core_data = pd.json_normalize(data['cores'])
payload_data = pd.json_normalize(data['payloads'])

# Combine all data into one DataFrame
df = pd.concat([data.reset_index(drop=True), core_data, payload_data], axis=1)

# Build the final DataFrame
launch_dict = {
    'FlightNumber': df['flight_number'],
    'Date': df['date'],
    'BoosterVersion': df['rocket'],  # This is just an ID; enriching it would require an API call
    'PayloadMass': df.get('mass_kg', np.nan),
    'Orbit': df.get('orbit', np.nan),
    'LaunchSite': df['launchpad'],  # Also just an ID
    'Outcome': df.get('landing_success', np.nan),
    'Flights': df.get('flight', np.nan),
    'GridFins': df.get('gridfins', np.nan),
    'Reused': df.get('reused', np.nan),
    'Legs': df.get('legs', np.nan),
    'LandingPad': df.get('landpad', np.nan),
    'Block': df.get('block', np.nan),
    'ReusedCount': df.get('reuse_count', np.nan),
    'Serial': df.get('core_serial', np.nan),
    'Longitude': df.get('longitude', np.nan),
    'Latitude': df.get('latitude', np.nan),
}

launch_df = pd.DataFrame(launch_dict)

# Display the top 5 rows
print(launch_df.head())
# Out:
#    FlightNumber        Date            BoosterVersion  PayloadMass  Orbit  \
# 0             1  2006-03-24  5e9d0d95eda69955f709d1eb          NaN    NaN
# 1             2  2007-03-21  5e9d0d95eda69955f709d1eb          NaN    NaN
# 2             4  2008-09-28  5e9d0d95eda69955f709d1eb          NaN    NaN
# 3             5  2009-07-13  5e9d0d95eda69955f709d1eb          NaN    NaN
# 4             6  2010-06-04  5e9d0d95eda69973a809d1ec          NaN    NaN
#
#                  LaunchSite Outcome  Flights  GridFins  Reused   Legs  \
# 0  5e9e4502f5090995de566f86    None        1     False   False  False
# 1  5e9e4502f5090995de566f86    None        1     False   False  False
# 2  5e9e4502f5090995de566f86    None        1     False   False  False
# 3  5e9e4502f5090995de566f86    None        1     False   False  False
# 4  5e9e4501f509094ba4566f84    None        1     False   False  False
#
#   LandingPad  Block  ReusedCount  Serial  Longitude  Latitude
# 0       None    NaN          NaN     NaN        NaN       NaN
# 1       None    NaN          NaN     NaN        NaN       NaN
# 2       None    NaN          NaN     NaN        NaN       NaN
# 3       None    NaN          NaN     NaN        NaN       NaN
# 4       None    NaN          NaN     NaN        NaN       NaN

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# URL of the Wikipedia page containing SpaceX launch data
url = 'https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches'

# Send a request and parse the page content
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
# Find all tables on the page
tables = soup.find_all('table', class_='wikitable')

# Display how many tables were found
print(f"Found {len(tables)} tables.")
launch_data = []

for table in tables:
    rows = table.find_all("tr")[1:]  # Skip header row
    for row in rows:
        cols = row.find_all("td")
        if len(cols) > 5:
            date = cols[0].text.strip().split("\n")[0]
            rocket = cols[1].text.strip()
            site = cols[2].text.strip()
            payload = cols[3].text.strip()
            orbit = cols[4].text.strip()
            outcome = cols[5].text.strip()
            booster_landing = cols[-1].text.strip()

            launch_data.append([date, rocket, site, payload, orbit, outcome, booster_landing])
columns = ["Date", "Rocket", "Launch Site", "Payload", "Orbit", "Launch Outcome", "Booster Landing"]
df = pd.DataFrame(launch_data, columns=columns)
df.head()
df.to_csv("spacex_launch_data.csv", index=False)
# Out:
# Found 6 tables.

# %%
df = df.replace(r'\[.*?\]', '', regex=True)
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Year'] = df['Date'].dt.year

df['Launch Success'] = df['Launch Outcome'].apply(lambda x: 1 if 'Success' in x or 'Operational' in x else 0)

df['Booster Landing Success'] = df['Booster Landing'].apply(
    lambda x: 1 if 'success' in x.lower() else (0 if 'failure' in x.lower() else None)
)
# Check for missing values
print(df.isnull().sum())

# Drop rows with missing critical values
df = df.dropna(subset=['Date', 'Launch Site', 'Payload', 'Orbit'])
df = df[['Date', 'Year', 'Rocket', 'Launch Site', 'Payload', 'Orbit',
         'Launch Outcome', 'Launch Success', 'Booster Landing', 'Booster Landing Success']]
print(df.head())
print(df.info())
# Out:
# Date                       338
# Rocket                       0
# Launch Site                  0
# Payload                      0
# Orbit                        0
# Launch Outcome               0
# Booster Landing              0
# Year                       338
# Launch Success               0
# Booster Landing Success    102
# dtype: int64
#           Date    Year Rocket         Launch Site  \
# 305 2025-06-21  2025.0  F9 B5  Vandenberg, SLC‑4E
# 306 2025-06-01  2025.0  F9 B5            TBA (FL)
# 307 2025-06-01  2025.0  F9 B5            TBA (FL)
# 310 2025-07-01  2025.0  F9 B5            TBA (FL)
# 311 2025-07-01  2025.0  F9 B5            TBA (FL)
#
#                                  Payload      Orbit  \
# 305  Transporter-14 (smallsat rideshare)        SSO
# 306                       Nusantara Lima       GTO?
# 307     Bandwagon-4 (smallsat rideshare)        LEO
# 310                              Crew-11  LEO (ISS)
# 311                 MTG-S1 — Sentinel-4A        GTO
#
#                    Launch Outcome  Launch Success  \
# 305                       Various               0
# 306  PT Pasifik Satelit Nusantara               0
# 307                       Various               0
# 310                    NASA (CCP)               0
# 311                      EUMETSAT               0
#
#                   Booster Landing  Booster Landing Success
# 305                       Various                      NaN
# 306  PT Pasifik Satelit Nusantara                      NaN
# 307                       Various                      NaN
# 310                    NASA (CCP)                      NaN
# 311                      EUMETSAT                      NaN
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 305 to 388
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     52 non-null     datetime64[ns]
#  1   Year                     52 non-null     float64
#  2   Rocket                   52 non-null     object
#  3   Launch Site              52 non-null     object
#  4   Payload                  52 non-null     object
#  5   Orbit                    52 non-null     object
#  6   Launch Outcome           52 non-null     object
#  7   Launch Success           52 non-null     int64
#  8   Booster Landing          52 non-null     object
#  9   Booster Landing Success  0 non-null      float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 4.5+ KB
# None
# <ipython-input-15-d275bbb3dc01>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# <ipython-input-15-d275bbb3dc01>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
